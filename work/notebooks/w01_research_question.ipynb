# %% [markdown]
# <a href="https://colab.research.google.com/github/TANISHQ-28/FlyRank-AI/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/TANISHQ-28/FlyRank-AI/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*
#
# ### My lane :
# Lane 1: Ranking Signal Analysis
#
# I chose this lane because my initial data exploration revealed a clear correlation between character count and click-through rates. I want to quantify this relationship to provide evidence-based recommendations on content length for better user engagement.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*
#
# ### Answer :
# Decision:
#
# My work aims to improve the decision-making process for content optimization. Specifically, it helps determine whether content length (character count) should be adjusted as part of a page refresh strategy to improve engagement.
#
# Action:
#
# The findings will be used by the content strategy or editorial team. Based on the observed relationship between character count and CTR, they can take action by prioritizing pages for 'length-tuning' refreshes—either shortening content that is too dense or expanding content that is too thin to better meet user expectations.
#
# Cost of a wrong call:
#
# A wrong recommendation (e.g., suggesting a length change that does not improve CTR) results in 'wasted effort'. If the team spends hours rewriting a page based on an incorrect signal, they lose the opportunity to work on higher-impact tasks. Furthermore, if content is artificially shortened or lengthened to hit a target that doesn't actually align with user intent, it could lead to a temporary dip in organic search performance.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*
#
# ## PS - "I am uploading almost every code to connect the COLAB with the NOTEBOOK so that no error could be generated and the answer can be uploaded successfuly".
#
# ### I wanted to see if my hunch about character count held up with some actual numbers. I ran a quick correlation and grouped the data into buckets to see if the relationship was steady or if it dropped off at certain lengths. The numbers I'm seeing suggest that [insert your correlation result here]—it’s not a massive 'magic' number, but it’s definitely a strong enough signal to keep digging into over the next few weeks.

# %%
import os, sys, subprocess

IN_COLAB = "google.colab" in sys.modules
REPO_URL = "https://github.com/flyrank-bih/flyrank-ml-internship-starter"
REPO_DIR = "flyrank-ml-internship-starter"

if IN_COLAB:
    if not os.path.isdir(REPO_DIR):
        subprocess.run(["git", "clone", "--depth", "1", REPO_URL, REPO_DIR], check=True)
    os.chdir(REPO_DIR)
    subprocess.run([sys.executable, "-m", "pip", "install", "-q", "-r", "requirements.txt"], check=True)
else:
    # find the repo root from wherever this kernel started
    while not os.path.isdir("data/raw") and os.getcwd() != "/":
        os.chdir("..")

print("Working dir:", os.getcwd())
assert os.path.exists("data/raw/content_refresh_anonymized.csv"), "starter CSV not found — are you at the repo root?"
print("Starter data found. You're ready.")

#  RUN THE WHOLE PIPELINE
# !{sys.executable} scripts/run_all.py

# IMPORTING JSON
import json
res = json.load(open("outputs/model_results.json"))

base = res["baseline"]["baseline_precision_at_50"]
rf   = res["models"]["random_forest"]["precision_at_50"]

#ANSWER:
import pandas as pd
import numpy as np

# Load the dataset
# The starter repo structure keeps the raw data in this path
df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

# 1. Analyze correlation between character count and clicks
corr = df["char_count"].corr(df["clicks_90d"])
print(f"Correlation between character count and clicks: {corr:.3f}")

# 2. Group by character count buckets to see the trend
df['char_count_bucket'] = pd.cut(df['char_count'], bins=5)
bucket_analysis = df.groupby('char_count_bucket', observed=True)['clicks_90d'].mean()

print("\nAverage clicks per character count bucket:")
print(bucket_analysis)

# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# Out:
# Working dir: /content/flyrank-ml-internship-starter
# Starter data found. You're ready.
#
# ...
# ▶ Step 1/5 — Prepare features — clean the data, build the feature vector, define the label
# ...
# Prepared 30,000 rows from 30,000 raw rows
# Wrote /content/flyrank-ml-internship-starter/data/processed/refresh_feature_vector.csv
#
# ...
# ▶ Step 2/5 — Baseline — a transparent hand-written rule to beat
# ...
# Wrote baseline queue: /content/flyrank-ml-internship-starter/data/processed/baseline_refresh_queue.csv
# Top-50 declining rate (full data, not the evaluated holdout Precision@50): 0.340
#
# ...
# ▶ Step 3/5 — Train — logistic regression, decision tree, random forest (client-holdout split)
# ...
# Trained 3 models on 30,000 rows
# Split strategy: client_holdout
# Best model: random_forest
# Wrote predictions: /content/flyrank-ml-internship-starter/data/processed/model_predictions.csv
# Wrote model results: /content/flyrank-ml-internship-starter/outputs/model_results.json
#
# ...

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*
#
# ## ANSWER :
# ### I want to be clear that this research is just me looking at what has happened in the past—it’s observed and directional. I’m using this to provide decision-support, not to say I’ve cracked the code on Google’s algorithm. I’m not claiming that adding characters will cause more clicks to happen, but rather that length seems to be a reliable signal we can look at to help us prioritize our work. It’s just one tool in the toolbox, not a guarantee.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [x] Every section above is filled — markdown thinking AND the code that backs it
# - [x] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [x] No client names, URLs, or private queries anywhere
# - [x] My claims use careful words: observed, measured, directional, decision-support
# - [x] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
